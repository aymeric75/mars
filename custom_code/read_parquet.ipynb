# %%
import pandas as pd
#pd.set_option("display.expand_frame_repr", False)
#pd.set_option("display.width", 40000)
df = pd.read_parquet("../data/GOOGL_2025-12-04_snapshots_10.parquet")

print(df.iloc[180005:190005])

#target = pd.Timedelta("0 days 09:30:45.732375581")
#df["Time_td"] = pd.to_timedelta(df["Time"], unit="ns")

#######

"""
print(df.loc[
    (df["Time_td"] >= target - pd.Timedelta("5 ms")) &
    (df["Time_td"] <= target + pd.Timedelta("5 ms"))
])
"""


#print(pd.Timedelta("0 days 09:30:45.732375581").value)

#print(df[:10])
#print(df.iloc[:, :10].head(29))
# Out:
#                   Time    Step  Ask_Price_1  Ask_Size_1  Bid_Price_1  \
# 180005  34245732375581  180005    3202600.0       541.0    3201700.0
# 180006  34245732375581  180006    3202600.0       541.0    3201700.0
# 180007  34245732375581  180007    3202600.0       541.0    3201700.0
# 180008  34245732375581  180008    3202600.0       541.0    3201700.0
# 180009  34245732375581  180009    3202600.0       541.0    3201700.0
# ...                ...     ...          ...         ...          ...
# 190000  34247635951738  190000    3204900.0       200.0    3203900.0
# 190001  34247635951738  190001    3204900.0       200.0    3203900.0
# 190002  34247635951738  190002    3204900.0       200.0    3203900.0
# 190003  34247645169478  190003    3204900.0       200.0    3203900.0
# 190004  34247645169478  190004    3204900.0       200.0    3203900.0
#
#         Bid_Size_1  Ask_Price_2  Ask_Size_2  Bid_Price_2  Bid_Size_2  ...  \
# ...
