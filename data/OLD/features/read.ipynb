# %%
import pandas as pd
train = pd.read_parquet("features_AMZN_2025-12-11_messages_10.parquet")
print(train)
# Out:
#                i            Time     f0  f1  f2   f3     f4  f5  f6  f7  f8  \
# 0          36467  34200002029295  35796   9   9  467  19799   0   0   0   9
# 1          36468  34200002332146  38288   4   9  467  19799   0   0   0   9
# 2          36469  34200002344473  38288   3   9  467  19799   0   0   0   9
# 3          36470  34200002354055  39312   4   9  464  19799   0   0   0   0
# 4          36471  34200002363239  38288   4   9  464  19799   0   0   0   0
# ...          ...             ...    ...  ..  ..  ...    ...  ..  ..  ..  ..
# 3812230  3865717  57599997830644  14720   9   0  436  43199   0   9  30   5
# 3812231  3865718  57599997831046  47488   9   9  436  43199   0   9  30   5
# 3812232  3865719  57599997831046  14720   9   0  436  43199   0   9  30   5
# 3812233  3865720  57599997888553   8688   1   0  436  43199   0   9  30   5
# 3812234  3865721  57599998796283  38274   9   9  436  43199   0   9  30   5
#
#          f9  f10  f11  f12  f13  f14
# ...
