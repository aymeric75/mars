# %%
import zarr
from zarr.storage import DirectoryStore

#images-tokens_AMZN-2025-12-11.zarr
#images-tokens_AMZN-2025-12-11.zarr
zip_path = "images-tokens_AMZN-2025-12-11.zarr"
result = zarr.open(DirectoryStore(zip_path), path="", mode="r")

print(result)
# Out:
# <zarr.core.Array (3812235, 64) int32 read-only>
