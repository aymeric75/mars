# %%
import pandas as pd

# AAPL_2025-12-17
feats = pd.read_parquet("features_AMZN_2025-12-11_cut.parquet")
print(len(feats))

past16 = pd.read_parquet("past16_AMZN_2025-12-11_cut.parquet")
print(len(past16))

next1 = pd.read_parquet("next1_AMZN_2025-12-11_cut.parquet")
print(len(next1))
# Out:
#                    Time     f0  f1  f2   f3     f4  f5  f6  f7  f8  f9  f10  \
# 390710   35160005954916   9335   2   0  482  20759  24  16  16   4   0    0
# 390711   35160005958042  39024   1   9  482  20759  24  16  16   4   0    0
# 390712   35160005995407  39296   3   9  482  20759  24  16   5   4   0    0
# 390713   35160007472447  39139   4   9  482  20759  24  16   5   2   0    0
# 390714   35160007528504  22240   1   0  482  20759  24  16   5   2   0    0
# ...                 ...    ...  ..  ..  ...    ...  ..  ..  ..  ..  ..  ...
# 3776534  57539995385648  41928   1   9  434  43139  10  23  24  29  32   31
# 3776535  57539995427155   8672   2   0  434  43139  10  23  24  29  32   31
# 3776536  57539997243903  38819   9   9  434  43139  10  23  24  29  32   31
# 3776537  57539997307999  42912   0   9  434  43139  10  23  24  29  32   31
# 3776538  57539997523358  42512   9   9  434  43139  10  23  24  29  32   31
#
#          f11  f12  f13  f14
# ...
