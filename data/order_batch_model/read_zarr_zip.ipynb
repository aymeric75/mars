# %%
import zarr
import numpy as np
import os
from zarr.storage import ZipStore
from pathlib import Path


#
#with ZipStore("images-tokens_AMZN-2025-12-11.zarr", mode="r") as store:
with ZipStore("next1_tokens_AMZN-2025-12-11.zarr.zip", mode="r") as store:
    arr = zarr.open(store=store, path="", mode="r")

    print(arr)

    #print(arr[:15].shape)
    # img = arr[123]        # single image
    # batch = arr[100:132] # batch
# Out:
# <zarr.core.Array (3385829, 64) int32 read-only>
