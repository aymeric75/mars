# %%
import pandas as pd


# /projappl/project_2012747/mars/MarS/data/ensemble_model/train/features
red = pd.read_parquet("features_AMZN_2025-12-09_cut_tenth.parquet")

print(red)

#half = red.iloc[:len(red)//10]

#half.to_parquet("features_AMZN_2025-12-09_cut_tenth.parquet", index=False)

#print(red)
# Out:
#                   Time     f0  f1  f2   f3     f4  f5  f6  f7  f8  f9  f10  \
# 0       35160006826206  39142   2   9   60  20759  32  17   5   4   4    0
# 1       35160006836651   8416   1   0   60  20759  32  17   5   4   4    0
# 2       35160006842581  42720   9   9   60  20759  32  17   5   4   4    0
# 3       35160007458170  43393   9   9   60  20759  32  17   5   4   4    0
# 4       35160007458170  10624   9   0   60  20759  32  17   5   4   4    0
# ...                ...    ...  ..  ..  ...    ...  ..  ..  ..  ..  ..  ...
# 229546  36155703621774  10624   9   0  117  21755   5  16   5  15  18    0
# 229547  36155703622132  43904   9   9  117  21755   5  16   5  15  18    0
# 229548  36155703622132  10624   9   0  117  21755   5  16   5  15  18    0
# 229549  36155703623008  46464   9   9  117  21755   5  16   5  15  18    0
# 229550  36155703623008  13696   9   0  117  21755   5  16   5  15  18    0
#
#         f11  f12  f13  f14
# 0         5    3    4    3
# ...
