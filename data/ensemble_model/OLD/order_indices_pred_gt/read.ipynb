# %%
#import zarr

#store_t = zarr.ZipStore("order_idxs_AAPL_2025-12-17_cut_targets.zarr.zip", mode="r")
#root_t  = zarr.open(store_t, mode="r")

#targets = root_t["target_f0"]      # shape (N,), int32
#print(targets.shape)

import zipfile

with zipfile.ZipFile("order_idxs_AMZN_2025-12-09_cut_tenth_targets.zarr.zip", "r") as z:
    z.extractall()
