# %%
"""
import zarr

logits_store = zarr.ZipStore("logitss_AMZN_2025-12-09_cut_tenth_top64.zarr.zip", mode="r")
#targets_store = zarr.ZipStore("order_idx_AAPL_2025-12-17_cut_targets.zarr.zip", mode="r")

root = zarr.open(logits_store, mode="r")

topk_idx   = root["topk_idx"]      # shape (N, K), int32
topk_logit = root["topk_logit"]    # shape (N, K), float16

print(topk_idx.shape, topk_logit.shape
"""
import zarr
src = zarr.open("topk_logit", mode="r")
print(src[:].max())
print(src[:].min())
"""
import zipfile

with zipfile.ZipFile("logitss_AMZN_2025-12-09_cut_tenth_top64.zarr.zip", "r") as z:
    z.extractall()

"""
# Out:
# 13.61
# 0.204
# '\nimport zipfile\n\nwith zipfile.ZipFile("logitss_AMZN_2025-12-09_cut_tenth_top64.zarr.zip", "r") as z:\n    z.extractall()\n\n'
